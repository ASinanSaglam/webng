# %%
# Make sure you are in the folder where you have the repo cloned
import os 
print(os.getcwd())
# Out:
# /home/monoid/Development/BNG_WESTPA_pipeline

# %%
# Make sure the configuration file is set correctly here
configuration_file = "opts.yaml"
# Now we are loading the file as an object to modify as necessary
import yaml 
f = open(configuration_file, "r")
conf = yaml.load(f)
f.close()
print(conf)
# Out:
# {'sampling_options': {'tau': 100, 'max_iter': 10, 'dimensions': 2, 'pcoord_length': 10}, 'binning_options': {'traj_per_bin': 100, 'block_size': 10, 'max_centers': 300, 'center_freq': 1}, 'path_options': {'sim_name': '/home/monoid/Development/BNG_WESTPA_pipeline/test_sim', 'bng_path': '/home/monoid/apps/BioNetGen-2.4.0', 'WESTPA_path': '/home/monoid/apps/westpa', 'bngl_file': '/home/monoid/Development/BNG_WESTPA_pipeline/test.bngl'}}

# %%
# Fixing paths to everything in the configuration file
# I suggest using absolute paths for everything here
WESTPA_path = "/home/monoid/apps/westpa"
BNG_path = "/home/monoid/apps/BioNetGen-2.4.0"
bngl_path = "/home/monoid/Development/BNG_WESTPA_pipeline/test.bngl"
sim_name = "/home/monoid/Development/BNG_WESTPA_pipeline/test_sim"

conf['path_options']['sim_name'] = sim_name
conf['path_options']['bngl_file'] = bngl_path
conf['path_options']['bng_path'] = BNG_path
conf['path_options']['WESTPA_path'] = WESTPA_path

# You can change the sampling parameters here
# in particular, if you have a simulation that a different number of progress coordinates (default here is 2)
# you MUST change the "dimensions" parameters to the correct value (e.g. if you want to track 8 gene expressions
# dimensions must be set to 8)

# %%
# TODO: Talk about all parameters you can set here
# Let's try running for 10 iterations to keep it short
conf['sampling_options']['max_iter'] = 10

# %%
# Let's remove the original and overwrite the configuration file with the new parameters
# make sure the file is closed when you try this
os.remove(configuration_file)
f = open(configuration_file, "w")
yaml.dump(conf, f)
f.close()

# %%
# %%bash
# # Now we will run the python command, make sure the yaml file matches "configuration_file"
# python bng_to_we.py -opts opts.yaml > bng_we.log

# %%
os.chdir(sim_name)
# We should be in the WESTPA simulation directory now
os.listdir(os.getcwd())
# Out:
# ['west.cfg',
#  'bngl_conf',
#  'init.sh',
#  'run.sh',
#  'system.py',
#  'bstates',
#  'aux_functions.py',
#  'env.sh',
#  'westpa_scripts']

# %%
# %%bash
# # This is the simulation initialization
# ./init.sh
# Out:
# -- WARNING  [py.warnings] -- /home/monoid/apps/anaconda2/lib/python2.7/site-packages/scipy/spatial/__init__.py:96: ImportWarning: Not importing directory '/home/monoid/apps/anaconda2/lib/python2.7/site-packages/scipy/spatial/qhull': missing __init__.py
#   from .qhull import *
#
# System is being built only off of the system driver
# Creating HDF5 file '/home/monoid/Development/BNG_WESTPA_pipeline/test_sim/west.h5'
# 0 target state(s) present
# Calculating progress coordinate values for basis states.
# 1 basis state(s) present
# Preparing initial states
#
#         Total bins:            1
#         Initial replicas:      100 in 1 bins, total weight = 1
#         Total target replicas: 100
#
# Simulation prepared.
# 1 of 1 (100.000000%) active bins are populated
# per-bin minimum non-zero probability:       1
# per-bin maximum probability:                1
# per-bin probability dynamic range (kT):     0
# per-segment minimum non-zero probability:   0.01
# per-segment maximum non-zero probability:   0.01
# per-segment probability dynamic range (kT): 0
# norm = 1, error in norm = -1.11022e-16 (-0.5*epsilon)
# /home/monoid/apps/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# %%bash
# # Run the simulation with 20 cores
# ./run.sh --n-workers 20
# # Unfortunate thing about running the simulation from a notebook is that the logging won't appear until the
# # simulation is done. If you want to check the progress, you might want to check the contents of the
# # traj_segs folder
# Out:
# -- WARNING  [py.warnings] -- /home/monoid/apps/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
#
# -- WARNING  [py.warnings] -- /home/monoid/apps/anaconda2/lib/python2.7/site-packages/scipy/spatial/__init__.py:96: ImportWarning: Not importing directory '/home/monoid/apps/anaconda2/lib/python2.7/site-packages/scipy/spatial/qhull': missing __init__.py
#   from .qhull import *
#
# System is being built only off of the system driver
# -- WARNING  [py.warnings] -- /home/monoid/apps/anaconda2/lib/python2.7/site-packages/scipy/optimize/_minimize.py:37: ImportWarning: Not importing directory '/home/monoid/apps/anaconda2/lib/python2.7/site-packages/scipy/optimize/lbfgsb': missing __init__.py
#   from .lbfgsb import _minimize_lbfgsb
#
# -- WARNING  [westext.adaptvoronoi.adaptVor_driver] -- Initializing voronoi centers from data failed;                         Using definition in system instead.
# westext.adaptvoronoi: Updating bin mapper
#
# -adaptive voronoi mapping --------------
#
# enabled: True
#
# max centers: 300
#
# center adding freq: 1
#
# centers: [[ 4. 18.]]
#
# ----------------------------------------
#
# Maximum wallclock time: 3 days, 0:00:00
#
# Tue Apr  9 09:36:26 2019
# Iteration 1 (10 requested)
# Beginning iteration 1
# 100 segments remain in iteration 1 (100 total)
# 1 of 1 (100.000000%) active bins are populated
# per-bin minimum non-zero probability:       1
# per-bin maximum probability:                1
# per-bin probability dynamic range (kT):     0
# per-segment minimum non-zero probability:   0.01
# per-segment maximum non-zero probability:   0.01
# per-segment probability dynamic range (kT): 0
# norm = 1, error in norm = -1.11022e-16 (-0.5*epsilon)
# westext.adaptvoronoi: Updating Voronoi centers
#
# westext.adaptvoronoi: Updating bin mapper
#
# Iteration wallclock: 0:00:00.290364, cputime: 0:00:00.432000
#
#
# Tue Apr  9 09:36:26 2019
# Iteration 2 (10 requested)
# Beginning iteration 2
# 100 segments remain in iteration 2 (100 total)
# 2 of 2 (100.000000%) active bins are populated
# per-bin minimum non-zero probability:       0.02
# per-bin maximum probability:                0.98
# per-bin probability dynamic range (kT):     3.89182
# per-segment minimum non-zero probability:   0.01
# per-segment maximum non-zero probability:   0.01
# per-segment probability dynamic range (kT): 0
# norm = 1, error in norm = -1.11022e-16 (-0.5*epsilon)
# westext.adaptvoronoi: Updating Voronoi centers
#
# westext.adaptvoronoi: Updating bin mapper
#
# Iteration wallclock: 0:00:00.326135, cputime: 0:00:00.456000
#
#
# Tue Apr  9 09:36:27 2019
# Iteration 3 (10 requested)
# Beginning iteration 3
# 200 segments remain in iteration 3 (200 total)
# 2 of 3 (66.666667%) active bins are populated
# per-bin minimum non-zero probability:       0.19
# per-bin maximum probability:                0.81
# per-bin probability dynamic range (kT):     1.45001
# per-segment minimum non-zero probability:   0.0002
# per-segment maximum non-zero probability:   0.01
# per-segment probability dynamic range (kT): 3.91202
# norm = 1, error in norm = -1.11022e-16 (-0.5*epsilon)
# westext.adaptvoronoi: Updating Voronoi centers
#
# westext.adaptvoronoi: Updating bin mapper
#
# Iteration wallclock: 0:00:00.377303, cputime: 0:00:00.924000
#
#
# Tue Apr  9 09:36:27 2019
# Iteration 4 (10 requested)
# Beginning iteration 4
# 300 segments remain in iteration 4 (300 total)
# 4 of 4 (100.000000%) active bins are populated
# per-bin minimum non-zero probability:       0.01
# per-bin maximum probability:                0.52
# per-bin probability dynamic range (kT):     3.95124
# per-segment minimum non-zero probability:   0.0001
# per-segment maximum non-zero probability:   0.01
# per-segment probability dynamic range (kT): 4.60517
# norm = 1, error in norm = 0 (0*epsilon)
# westext.adaptvoronoi: Updating Voronoi centers
#
# westext.adaptvoronoi: Updating bin mapper
#
# Iteration wallclock: 0:00:00.599272, cputime: 0:00:01.416000
#
#
# Tue Apr  9 09:36:28 2019
# Iteration 5 (10 requested)
# Beginning iteration 5
# 400 segments remain in iteration 5 (400 total)
# 5 of 5 (100.000000%) active bins are populated
# per-bin minimum non-zero probability:       0.00722222
# per-bin maximum probability:                0.492067
# per-bin probability dynamic range (kT):     4.22145
# per-segment minimum non-zero probability:   5e-05
# per-segment maximum non-zero probability:   0.008
# per-segment probability dynamic range (kT): 5.07517
# norm = 1, error in norm = 0 (0*epsilon)
# westext.adaptvoronoi: Updating Voronoi centers
#
# westext.adaptvoronoi: Updating bin mapper
#
# Iteration wallclock: 0:00:00.703753, cputime: 0:00:01.976000
#
#
# Tue Apr  9 09:36:28 2019
# Iteration 6 (10 requested)
# Beginning iteration 6
# 500 segments remain in iteration 6 (500 total)
# 5 of 6 (83.333333%) active bins are populated
# per-bin minimum non-zero probability:       0.0153472
# per-bin maximum probability:                0.54565
# per-bin probability dynamic range (kT):     3.57104
# per-segment minimum non-zero probability:   9.25926e-05
# per-segment maximum non-zero probability:   0.008
# per-segment probability dynamic range (kT): 4.45899
# norm = 1, error in norm = 2.22045e-16 (1*epsilon)
# westext.adaptvoronoi: Updating Voronoi centers
#
# westext.adaptvoronoi: Updating bin mapper
#
# Iteration wallclock: 0:00:00.920783, cputime: 0:00:02.544000
#
#
# Tue Apr  9 09:36:29 2019
# Iteration 7 (10 requested)
# Beginning iteration 7
# 600 segments remain in iteration 7 (600 total)
# 7 of 7 (100.000000%) active bins are populated
# per-bin minimum non-zero probability:       0.00173178
# per-bin maximum probability:                0.516879
# per-bin probability dynamic range (kT):     5.69866
# per-segment minimum non-zero probability:   2.68817e-05
# per-segment maximum non-zero probability:   0.00666667
# per-segment probability dynamic range (kT): 5.51343
# norm = 1, error in norm = 0 (0*epsilon)
# westext.adaptvoronoi: Updating Voronoi centers
#
# westext.adaptvoronoi: Updating bin mapper
#
# Iteration wallclock: 0:00:01.046186, cputime: 0:00:03.040000
#
#
# Tue Apr  9 09:36:30 2019
# Iteration 8 (10 requested)
# Beginning iteration 8
# 700 segments remain in iteration 8 (700 total)
# 8 of 8 (100.000000%) active bins are populated
# per-bin minimum non-zero probability:       0.00112052
# per-bin maximum probability:                0.514221
# per-bin probability dynamic range (kT):     6.12886
# per-segment minimum non-zero probability:   1.53846e-05
# per-segment maximum non-zero probability:   0.00666667
# per-segment probability dynamic range (kT): 6.07151
# norm = 1, error in norm = 0 (0*epsilon)
# westext.adaptvoronoi: Updating Voronoi centers
#
# westext.adaptvoronoi: Updating bin mapper
#
# Iteration wallclock: 0:00:01.574096, cputime: 0:00:03.668000
#
#
# Tue Apr  9 09:36:32 2019
# Iteration 9 (10 requested)
# Beginning iteration 9
# 800 segments remain in iteration 9 (800 total)
# 9 of 9 (100.000000%) active bins are populated
# per-bin minimum non-zero probability:       0.000366589
# per-bin maximum probability:                0.451135
# per-bin probability dynamic range (kT):     7.11528
# per-segment minimum non-zero probability:   3.14236e-06
# per-segment maximum non-zero probability:   0.00666667
# per-segment probability dynamic range (kT): 7.6599
# norm = 1, error in norm = 0 (0*epsilon)
# westext.adaptvoronoi: Updating Voronoi centers
#
# westext.adaptvoronoi: Updating bin mapper
#
# Iteration wallclock: 0:00:01.435325, cputime: 0:00:04.220000
#
#
# Tue Apr  9 09:36:33 2019
# Iteration 10 (10 requested)
# Beginning iteration 10
# 800 segments remain in iteration 10 (800 total)
# 9 of 10 (90.000000%) active bins are populated
# per-bin minimum non-zero probability:       0.00404919
# per-bin maximum probability:                0.468612
# per-bin probability dynamic range (kT):     4.75126
# per-segment minimum non-zero probability:   3.60082e-05
# per-segment maximum non-zero probability:   0.00666667
# per-segment probability dynamic range (kT): 5.22113
# norm = 1, error in norm = 0 (0*epsilon)
# westext.adaptvoronoi: Updating Voronoi centers
#
# westext.adaptvoronoi: Updating bin mapper
#
# Iteration wallclock: 0:00:01.429513, cputime: 0:00:04.212000
#
#
# Tue Apr  9 09:36:35 2019
# WEST run complete.

# %%
# %%bash
# source /home/monoid/apps/westpa/westpa.sh
# # We need these two files in the analysis folder for it to work. You can symlink if you prefer/have a large HDF5
# # file (west.h5 by default)
# cp west.h5 ../WESTPA_BNG_analysis/.
# cp system.py ../WESTPA_BNG_analysis/.
# cd ../WESTPA_BNG_analysis/
# # The following script will attempt to do:
# # * Make probability distributions using WESTPA tool w_pdist and generate X by X set of plots in a single image
# # where X is the number of progress coordinate dimensions. The diagonal will be a 1D probability distribution
# # off diagonals will be 2D probability distributions. The image is called pdists.png by default
# # * Make another image called evolution.png where you can check the probability distribution evolutions of
# # every progress coordinate, x-axis is the WE iteration and y-axis is the progress coordinate, there will be a plot
# # for every coordinate.
# # * Make a file containing transition matrix information called tmat.h5
# # * Use that file to do PCCA+ clustering using clustering.py
# # * Generate .gml files, one for the full network, one for phenotype transition network called vor_coarse.gml and
# # vor_full.gml. You can use a network imaging program to visualize these files (e.g. Gephi, yEd)
#
# # Note, PCCA+ clustering might fail if your transition matrix is not reversible:
# # http://www.emma-project.org/v2.4/api/generated/pyemma.msm.PCCA.html
# # You can try to cirvumvent this check in PyEMMA code if you want to get an estimate of the PCCA+ clustering
# # but that's beyond the scope of this tutorial
#
# # Argument 1: Starting WE iteration for the analyses to run, you want to average the analysis after achieveing
# # a steady-state
# # Argument 2: The number of clusters to automatically cluster to using PCCA+
# ./run_all_analysis.sh 1 4
# Out:
# ### Plotting every prob dist ###
# ### Plotting prob dist evolutions ###
# ### Assigning to voronoi bins ###
# Initializing...
# Assigning to bins...
# ### Making the transition matrix ###
# Initializing...
# Calculating flux matrices...
# ### Doing PCCA+ ###
# Averaged transition matrix
# (array([[1.10e-01, 6.02e-02, 2.32e-02, 4.07e-02, 0.00e+00, 0.00e+00,
#         9.45e-04, 2.15e-02, 0.00e+00, 5.94e-03],
#        [2.90e-03, 2.69e+00, 3.66e-01, 1.94e+00, 1.11e-03, 1.30e-02,
#         0.00e+00, 0.00e+00, 1.86e-03, 8.33e-05],
#        [1.28e-02, 3.34e-01, 5.17e-02, 2.93e-01, 1.30e-03, 9.51e-03,
#         1.40e-04, 3.50e-03, 1.41e-03, 1.56e-03],
#        [1.09e-02, 1.97e+00, 2.60e-01, 1.50e+00, 0.00e+00, 3.63e-03,
#         9.30e-05, 1.05e-03, 0.00e+00, 5.14e-04],
#        [0.00e+00, 8.31e-04, 1.72e-03, 0.00e+00, 2.43e-03, 1.77e-02,
#         0.00e+00, 0.00e+00, 2.94e-03, 0.00e+00],
#        [0.00e+00, 5.71e-03, 1.04e-02, 5.87e-03, 1.85e-02, 1.13e-01,
#         0.00e+00, 0.00e+00, 1.77e-02, 0.00e+00],
#        [1.06e-03, 0.00e+00, 6.99e-05, 4.70e-05, 0.00e+00, 0.00e+00,
#         1.05e-06, 1.66e-04, 0.00e+00, 1.04e-05],
#        [2.16e-02, 0.00e+00, 2.13e-03, 1.33e-03, 0.00e+00, 0.00e+00,
#         1.98e-04, 4.59e-03, 0.00e+00, 9.52e-04],
#        [0.00e+00, 1.40e-03, 9.89e-04, 0.00e+00, 3.21e-03, 1.77e-02,
#         0.00e+00, 0.00e+00, 3.07e-03, 0.00e+00],
#        [7.03e-03, 0.00e+00, 5.40e-04, 2.89e-04, 0.00e+00, 0.00e+00,
#         2.08e-05, 9.43e-04, 0.00e+00, 2.41e-04]]), (10, 10))
# ##### Clustering #####
# ##### Clustering results #####
# MSM probs
# [33.48  3.07  0.9  62.56]
# MSM TM
# [[-8.97e+01  1.54e+01  3.38e+02 -1.64e+02]
#  [ 4.05e+00  8.81e+01  2.63e-01  7.59e+00]
#  [ 1.37e+01  2.15e-01  6.04e+01  2.57e+01]
#  [ 1.01e+02 -7.68e+00 -1.80e+02  1.87e+02]]
# ##### Metastable states info #####
# loading bin labels
# bin labels loaded
# metastable state 0 with probability 33.48%
# 0 bins are assigned to this state
#  Atot   Btot
#    nan    nan
# metastable state 1 with probability 3.07%
# 3 bins are assigned to this state
#  Atot   Btot
#  22.33   5.00
# metastable state 2 with probability 0.90%
# 4 bins are assigned to this state
#  Atot   Btot
#   5.00  25.00
# metastable state 3 with probability 62.56%
# 3 bins are assigned to this state
#  Atot   Btot
#   5.00   5.67
# ### Making graphs ###
# /home/monoid/apps/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Traceback (most recent call last):
#   File "highdimplotter.py", line 8, in <module>
#     import assignment as asgn
#   File "/home/monoid/Development/BNG_WESTPA_pipeline/WESTPA_BNG_analysis/assignment.py", line 3, in <module>
#     from westpa.binning import NopMapper, RectilinearBinMapper
# ImportError: No module named westpa.binning
# /home/monoid/apps/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Traceback (most recent call last):
#   File "evoPlotter.py", line 8, in <module>
#     import assignment as asgn
#   File "/home/monoid/Development/BNG_WESTPA_pipeline/WESTPA_BNG_analysis/assignment.py", line 3, in <module>
#     from westpa.binning import NopMapper, RectilinearBinMapper
# ImportError: No module named westpa.binning
# /home/monoid/apps/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /home/monoid/apps/anaconda2/lib/python2.7/site-packages/scipy/spatial/__init__.py:96: ImportWarning: Not importing directory '/home/monoid/apps/anaconda2/lib/python2.7/site-packages/scipy/spatial/qhull': missing __init__.py
#   from .qhull import *
# /home/monoid/apps/anaconda2/lib/python2.7/site-packages/scipy/optimize/_minimize.py:37: ImportWarning: Not importing directory '/home/monoid/apps/anaconda2/lib/python2.7/site-packages/scipy/optimize/lbfgsb': missing __init__.py
#   from .lbfgsb import _minimize_lbfgsb
# /home/monoid/apps/anaconda2/lib/python2.7/site-packages/scipy/spatial/__init__.py:96: ImportWarning: Not importing directory '/home/monoid/apps/anaconda2/lib/python2.7/site-packages/scipy/spatial/qhull': missing __init__.py
#   from .qhull import *
# /home/monoid/apps/anaconda2/lib/python2.7/site-packages/scipy/optimize/_minimize.py:37: ImportWarning: Not importing directory '/home/monoid/apps/anaconda2/lib/python2.7/site-packages/scipy/optimize/lbfgsb': missing __init__.py
#   from .lbfgsb import _minimize_lbfgsb
# /home/monoid/apps/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /home/monoid/apps/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from IPython.display import Image
os.chdir("../WESTPA_BNG_analysis")
Image("pdists.png")

# %%
Image("evolution.png")
